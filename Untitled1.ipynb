# %%
import json
#data=[]
jsonFile="C:\\workplace\\data\\ms\\val\\via_region_data.json"


with open(jsonFile, 'r') as myfile:
    data=myfile.read()
person_json = json.dumps(data)

# Output: {"name": "Bob", "age": 12, "children": null}
#print(person_json)

dataF=json.loads(data)
print(dataF)
# Out:
# {'AA_first_IM_00028.jpg27891': {'fileref': '', 'size': 27891, 'filename': 'AA_first_IM_00028.jpg', 'base64_img_data': '', 'file_attributes': {}, 'regions': {'0': {'shape_attributes': {'name': 'polygon', 'all_points_x': [269, 269, 272, 272, 268, 262, 257, 255, 257, 262, 266, 266, 269], 'all_points_y': [341, 335, 331, 327, 327, 328, 330, 334, 337, 340, 342, 345, 341]}, 'region_attributes': {'label': 'msMask'}}}}, 'AA_first_IM_00034.jpg28123': {'fileref': '', 'size': 28123, 'filename': 'AA_first_IM_00034.jpg', 'base64_img_data': '', 'file_attributes': {}, 'regions': {'0': {'shape_attributes': {'name': 'polygon', 'all_points_x': [344, 345, 342, 335, 330, 330, 332, 337, 342, 344], 'all_points_y': [309, 317, 319, 321, 315, 310, 306, 305, 303, 309]}, 'region_attributes': {'label': 'msMask'}}}}, 'AA_first_IM_00039.jpg26595': {'fileref': '', 'size': 26595, 'filename': 'AA_first_IM_00039.jpg', 'base64_img_data': '', 'file_attributes': {}, 'regions': {'0': {'shape_attributes': {'name': 'polygon
# ...
