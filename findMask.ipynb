# %%
import matplotlib.image as img
import os
import glob
import cv2

root_dir = 'D:\\datasets\\ms\\isbi\\isbi200\\test\\'
mask_root_dir = 'D:\\datasets\\ms\\isbi\\isbiPNG\\maskPNG\\'
mask_target_dir='D:\\datasets\\ms\\isbi\\isbi200\\testMask\\'

all_images=sorted(glob.glob(os.path.join(root_dir,'*.jpg')))
# display(all_images)
for item in all_images:
    print("\n",item)
    fname=os.path.basename(item)
    maskFname=fname.replace("slice","GTmask")
    readMask=mask_root_dir+maskFname
    print("readMask:",readMask)
    mask=cv2.imread(readMask)
#     display(mask)
    writeMask=mask_target_dir+maskFname
    print("wMask:",writeMask)
    img.imsave(writeMask, mask)
# Out:
#  D:\datasets\ms\isbi\isbi200\test\parent_training01_mask1_slice_0045.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training01_mask1_GTmask_0045.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training01_mask1_GTmask_0045.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training01_mask1_slice_0052.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training01_mask1_GTmask_0052.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training01_mask1_GTmask_0052.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training01_mask1_slice_0057.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training01_mask1_GTmask_0057.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training01_mask1_GTmask_0057.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training01_mask1_slice_0064.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training01_mask1_GTmask_0064.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training01_mask1_GTmask_0064.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training01_mask1_slice_0069.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training01_mask1_GTmask_0069.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training01_mask1_GTmask_0069.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training01_mask1_slice_0076.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training01_mask1_GTmask_0076.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training01_mask1_GTmask_0076.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training01_mask1_slice_0081.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training01_mask1_GTmask_0081.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training01_mask1_GTmask_0081.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training01_mask1_slice_0088.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training01_mask1_GTmask_0088.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training01_mask1_GTmask_0088.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training01_mask1_slice_0093.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training01_mask1_GTmask_0093.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training01_mask1_GTmask_0093.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training01_mask1_slice_0100.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training01_mask1_GTmask_0100.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training01_mask1_GTmask_0100.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training01_mask1_slice_0105.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training01_mask1_GTmask_0105.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training01_mask1_GTmask_0105.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training01_mask1_slice_0112.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training01_mask1_GTmask_0112.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training01_mask1_GTmask_0112.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training01_mask1_slice_0117.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training01_mask1_GTmask_0117.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training01_mask1_GTmask_0117.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training02_mask1_slice_0055.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training02_mask1_GTmask_0055.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training02_mask1_GTmask_0055.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training02_mask1_slice_0060.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training02_mask1_GTmask_0060.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training02_mask1_GTmask_0060.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training02_mask1_slice_0067.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training02_mask1_GTmask_0067.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training02_mask1_GTmask_0067.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training02_mask1_slice_0072.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training02_mask1_GTmask_0072.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training02_mask1_GTmask_0072.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training02_mask1_slice_0079.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training02_mask1_GTmask_0079.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training02_mask1_GTmask_0079.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training02_mask1_slice_0084.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training02_mask1_GTmask_0084.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training02_mask1_GTmask_0084.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training02_mask1_slice_0091.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training02_mask1_GTmask_0091.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training02_mask1_GTmask_0091.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training02_mask1_slice_0096.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training02_mask1_GTmask_0096.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training02_mask1_GTmask_0096.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training02_mask1_slice_0103.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training02_mask1_GTmask_0103.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training02_mask1_GTmask_0103.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training02_mask1_slice_0108.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training02_mask1_GTmask_0108.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training02_mask1_GTmask_0108.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training02_mask1_slice_0115.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training02_mask1_GTmask_0115.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training02_mask1_GTmask_0115.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training02_mask1_slice_0120.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training02_mask1_GTmask_0120.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training02_mask1_GTmask_0120.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training02_mask1_slice_0127.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training02_mask1_GTmask_0127.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training02_mask1_GTmask_0127.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training02_mask1_slice_0132.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training02_mask1_GTmask_0132.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training02_mask1_GTmask_0132.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training03_mask1_slice_0052.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training03_mask1_GTmask_0052.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training03_mask1_GTmask_0052.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training03_mask1_slice_0066.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training03_mask1_GTmask_0066.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training03_mask1_GTmask_0066.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training03_mask1_slice_0073.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training03_mask1_GTmask_0073.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training03_mask1_GTmask_0073.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training03_mask1_slice_0078.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training03_mask1_GTmask_0078.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training03_mask1_GTmask_0078.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training03_mask1_slice_0085.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training03_mask1_GTmask_0085.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training03_mask1_GTmask_0085.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training03_mask1_slice_0090.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training03_mask1_GTmask_0090.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training03_mask1_GTmask_0090.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training03_mask1_slice_0097.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training03_mask1_GTmask_0097.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training03_mask1_GTmask_0097.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training03_mask1_slice_0102.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training03_mask1_GTmask_0102.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training03_mask1_GTmask_0102.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training03_mask1_slice_0109.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training03_mask1_GTmask_0109.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training03_mask1_GTmask_0109.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training03_mask1_slice_0114.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training03_mask1_GTmask_0114.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training03_mask1_GTmask_0114.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training03_mask1_slice_0121.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training03_mask1_GTmask_0121.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training03_mask1_GTmask_0121.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training04_mask1_slice_0053.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training04_mask1_GTmask_0053.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training04_mask1_GTmask_0053.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training04_mask1_slice_0071.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training04_mask1_GTmask_0071.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training04_mask1_GTmask_0071.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training04_mask1_slice_0076.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training04_mask1_GTmask_0076.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training04_mask1_GTmask_0076.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training04_mask1_slice_0083.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training04_mask1_GTmask_0083.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training04_mask1_GTmask_0083.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training04_mask1_slice_0088.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training04_mask1_GTmask_0088.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training04_mask1_GTmask_0088.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training04_mask1_slice_0097.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training04_mask1_GTmask_0097.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training04_mask1_GTmask_0097.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training04_mask1_slice_0102.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training04_mask1_GTmask_0102.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training04_mask1_GTmask_0102.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training05_mask1_slice_0051.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training05_mask1_GTmask_0051.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training05_mask1_GTmask_0051.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training05_mask1_slice_0069.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training05_mask1_GTmask_0069.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training05_mask1_GTmask_0069.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training05_mask1_slice_0076.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training05_mask1_GTmask_0076.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training05_mask1_GTmask_0076.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training05_mask1_slice_0081.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training05_mask1_GTmask_0081.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training05_mask1_GTmask_0081.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training05_mask1_slice_0088.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training05_mask1_GTmask_0088.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training05_mask1_GTmask_0088.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training05_mask1_slice_0093.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training05_mask1_GTmask_0093.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training05_mask1_GTmask_0093.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training05_mask1_slice_0100.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training05_mask1_GTmask_0100.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training05_mask1_GTmask_0100.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training05_mask1_slice_0105.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training05_mask1_GTmask_0105.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training05_mask1_GTmask_0105.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training05_mask1_slice_0112.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training05_mask1_GTmask_0112.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training05_mask1_GTmask_0112.jpg
#
#  D:\datasets\ms\isbi\isbi200\test\parent_training05_mask1_slice_0117.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNG\parent_training05_mask1_GTmask_0117.jpg
# wMask: D:\datasets\ms\isbi\isbi200\testMask\parent_training05_mask1_GTmask_0117.jpg

# %%
import os
import glob
import cv2


root_dir = 'D:\\datasets\\ms\\isbi\\isbiPNG\\train'
mask_root_dir = 'D:\\datasets\\ms\\isbi\\isbiPNG\\maskPNG'
mask_target_dir='D:\\datasets\\ms\\isbi\\isbiPNG\\trainMask'

all_images=sorted(glob.glob(os.path.join(root_dir,'*.jpg')))
# display(all_images)
for item in all_images:
    print(item)
    fname=os.path.basename(item)
    maskFname=fname.replace("slice","mask")
    readMask=mask_root_dir+maskFname
    print("readMask:",readMask)
    mask=cv2.imread(readMask)
    writeMask=mask_target_dir+maskFname
    print("wMask:",writeMask)
    cv2.imwrite(writeMask, mask)
# Out:
# D:\datasets\ms\isbi\isbiPNG\train\parent_training01_mask1_slice_0043.jpg
# readMask: D:\datasets\ms\isbi\isbiPNG\maskPNGparent_training01_mask1_mask_0043.jpg
# wMask: D:\datasets\ms\isbi\isbiPNG\trainMaskparent_training01_mask1_mask_0043.jpg
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-1-18a86e1b6b1a> in <module>
#      19     writeMask=mask_target_dir+maskFname
#      20     print("wMask:",writeMask)
# ---> 21     cv2.imwrite(writeMask, mask)
#
# error: OpenCV(4.4.0) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-2b5g8ysb\opencv\modules\imgcodecs\src\loadsave.cpp:738: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
